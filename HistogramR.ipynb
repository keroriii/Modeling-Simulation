# %%
grades <- c(20.00, 49.67, 92.00, 56.53, 73.07, 78.40, 68.13, 60.27, 88.13, 67.60,
            78.00, 65.87, 53.33, 65.47, 47.20, 65.20, 53.60, 80.53, 60.53, 75.33,
            66.20, 50.40, 69.13, 56.67, 60.53, 63.73, 56.27, 51.20, 66.67, 47.67,
            16.67, 50.27, 37.33, 81.20, 80.40, 59.73, 63.07, 58.80, 66.67, 65.07,
            65.60, 62.40, 81.73, 64.80)


hist(grades,
     main = "Midterm Grades Distribution - BSCS601",
     xlab = "Grade",
     ylab = "Number of Students",
     col = "skyblue",
     border = "white",
     breaks = seq(0, 100, by = 5),  # Bins from 0 to 100 in steps of 5
     xlim = c(0, 100))              # Set x-axis limits


abline(v = mean(grades), col = "red", lty = 2, lwd = 2)


legend("topright", 
       legend = paste("Mean =", round(mean(grades), 2)),
       col = "red",
       lty = 2,
       lwd = 2)
# Out:
# Plot with title "Midterm Grades Distribution - BSCS601"
